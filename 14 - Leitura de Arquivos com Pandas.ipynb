# %%
#importando a biblioteca do Pandas

import pandas as pd

# %%
#Lendo o arquivo sanduiches.txt

arquivo = pd.read_table('Sanduiches.txt')

# %%
arquivo.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %%
#Lendo o arquivo users.txt

arquivo = pd.read_table('users.txt')

arquivo.head()
# Out:
#    1|24|M|technician|85711
# 0       2|53|F|other|94043
# 1      3|23|M|writer|32067
# 2  4|24|M|technician|43537
# 3       5|33|F|other|15213
# 4   6|42|M|executive|98101

# %% [markdown]
# # Observe que a leitura foi feita de maneira errada

# %%
#Podemos ler o arquivo colocando um separador

arquivo = pd.read_table('users.txt', sep='|')
arquivo.head()
# Out:
#    1  24  M  technician  85711
# 0  2  53  F       other  94043
# 1  3  23  M      writer  32067
# 2  4  24  M  technician  43537
# 3  5  33  F       other  15213
# 4  6  42  M   executive  98101

# %%
arquivo = pd.read_table('users.txt', sep='|', header=None)
arquivo.head()
# Out:
#    0   1  2           3      4
# 0  1  24  M  technician  85711
# 1  2  53  F       other  94043
# 2  3  23  M      writer  32067
# 3  4  24  M  technician  43537
# 4  5  33  F       other  15213

# %%
colunas=['id','idade','sexo','profissao','cep']

arquivo = pd.read_table('users.txt', sep='|', header=None, names=colunas)
arquivo.head()
# Out:
#    id  idade sexo   profissao    cep
# 0   1     24    M  technician  85711
# 1   2     53    F       other  94043
# 2   3     23    M      writer  32067
# 3   4     24    M  technician  43537
# 4   5     33    F       other  15213

# %% [markdown]
# # Lendo outro tipo de arquivo

# %%
arquivo = pd.read_csv('ufo.csv')
arquivo.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %% [markdown]
# # E caso o arquivo tenha posições fixas

# %%
arquivo = pd.read_fwf('LarguraFixa.txt')
arquivo.head()
# Out:
#    USAF   WBAN STATION NAME CTRY   ST CALL  LAT  LON  ELEV(M)     BEGIN  \
# 0  7005  99999   CWOS 07005  NaN  NaN  NaN  NaN  NaN      NaN  20120127
# 1  7011  99999   CWOS 07011  NaN  NaN  NaN  NaN  NaN      NaN  20111025
# 2  7018  99999   WXPOD 7018  NaN  NaN  NaN  0.0  0.0   7018.0  20110309
# 3  7025  99999   CWOS 07025  NaN  NaN  NaN  NaN  NaN      NaN  20120127
# 4  7026  99999   WXPOD 7026   AF  NaN  NaN  0.0  0.0   7026.0  20120713
#
#         END
# 0  20120127
# 1  20121129
# 2  20130730
# 3  20120127
# 4  20141120

# %% [markdown]
# # E caso o meu arquivo seja separado por espaços irregulares?

# %%
arquivo = pd.read_csv('SepEspaco.txt')
arquivo.head()
# Out:
#   Year Month Day Hour Temp DewTemp Pressure WindDir WindSpeed Sky Precip1 Precip6
# 0      1912 4 1 6 114 94 10121 200 120 8 -9999 -9999
# 1      1912 4 1 9 146 96 10122 240 140 8 -9999 -9999
# 2         1912 4 2 6 172 122 10146 210 40 2 -9999 40
# 3       1912 4 2 9 193 -9999 10150 240 210 1 -9999 0
# 4        1912 4 2 12 188 125 10152 240 250 1 -9999 0

# %%
#Utilizaremos expressão regular. Lembram que '\s' significa espaço? Pegaremos então todos os espaços com '\s+'

regex = '\s+'

arquivo = pd.read_csv('SepEspaco.txt', sep=regex)
arquivo.head()
# Out:
#    Year  Month  Day  Hour  Temp  DewTemp  Pressure  WindDir  WindSpeed  Sky  \
# 0  1912      4    1     6   114       94     10121      200        120    8
# 1  1912      4    1     9   146       96     10122      240        140    8
# 2  1912      4    2     6   172      122     10146      210         40    2
# 3  1912      4    2     9   193    -9999     10150      240        210    1
# 4  1912      4    2    12   188      125     10152      240        250    1
#
#    Precip1  Precip6
# 0    -9999    -9999
# 1    -9999    -9999
# 2    -9999       40
# 3    -9999        0
# 4    -9999        0
